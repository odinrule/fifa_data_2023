# %%
import pandas as pd 
data_frame = pd.read_csv('FIFA23_official_data.csv')
data_frame.shape
# Out:
# (17660, 29)

# %%
data_frame.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   17660.000000  17660.000000  17660.000000  17660.000000  17660.000000
# mean   246319.424462     23.127746     63.369592     70.981200   1537.915855
# std     31487.892861      4.639821      8.036268      6.529836    285.893809
# min        16.000000     15.000000     43.000000     42.000000    749.000000
# 25%    240732.500000     20.000000     58.000000     67.000000   1387.000000
# 50%    257041.000000     22.000000     63.000000     71.000000   1548.000000
# 75%    263027.500000     26.000000     69.000000     75.000000   1727.000000
# max    271340.000000     54.000000     91.000000     95.000000   2312.000000
#
#        International Reputation     Weak Foot   Skill Moves    Kit Number
# count              17660.000000  17660.000000  17660.000000  17625.000000
# mean                   1.106285      2.900340      2.297169     25.037957
# std                    0.407021      0.663523      0.754264     19.154116
# min                    1.000000      1.000000      1.000000      1.000000
# 25%                    1.000000      3.000000      2.000000     11.000000
# 50%                    1.000000      3.000000      2.000000     22.000000
# 75%                    1.000000      3.000000      3.000000     32.000000
# max                    5.000000      5.000000      5.000000     99.000000

# %%
data_frame[data_frame['Age']>=40].head()
# Out:
#           ID            Name  Age  \
# 199   269760         R. Kent   40
# 997    41236  Z. Ibrahimović   40
# 1331   45186         Joaquín   40
# 2277  115909    Rubén Castro   41
# 3143  153260       21 Hilton   42
#
#                                                  Photo Nationality  \
# 199   https://cdn.sofifa.net/players/269/760/23_60.png     England
# 997   https://cdn.sofifa.net/players/041/236/23_60.png      Sweden
# 1331  https://cdn.sofifa.net/players/045/186/23_60.png       Spain
# 2277  https://cdn.sofifa.net/players/115/909/23_60.png       Spain
# 3143  https://cdn.sofifa.net/players/153/260/21_60.png      Brazil
#
#                                          Flag  Overall  Potential  \
# 199   https://cdn.sofifa.net/flags/gb-eng.png       83         83
# 997       https://cdn.sofifa.net/flags/se.png       82         82
# 1331      https://cdn.sofifa.net/flags/es.png       79         79
# 2277      https://cdn.sofifa.net/flags/es.png       73         73
# 3143      https://cdn.sofifa.net/flags/br.png       75         75
#
#                         Club                                   Club Logo  ...  \
# 199             AFC Richmond  https://cdn.sofifa.net/teams/116418/30.png  ...
# 997                 AC Milan      https://cdn.sofifa.net/teams/47/30.png  ...
# 1331     Real Betis Balompié     https://cdn.sofifa.net/teams/449/30.png  ...
# 2277               Málaga CF     https://cdn.sofifa.net/teams/573/30.png  ...
# 3143  Montpellier Hérault SC      https://cdn.sofifa.net/teams/70/30.png  ...
#
#      Real Face                     Position       Joined Loaned From  \
# 199        Yes  <span class="pos pos15">LCM  Jul 1, 2018         NaN
# 997        Yes  <span class="pos pos29">RES  Jan 2, 2020         NaN
# 1331       Yes  <span class="pos pos28">SUB  Sep 1, 2015         NaN
# 2277        No   <span class="pos pos26">LS  Jul 6, 2022         NaN
# 3143       Yes   <span class="pos pos4">RCB  Aug 1, 2011         NaN
#
#       Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 199                   2024   182cm    82kg            NaN        6.0
# 997                   2023   195cm   102kg            NaN       11.0
# 1331                  2023   179cm    75kg            NaN       17.0
# 2277                  2023   169cm    68kg            NaN       24.0
# 3143                  2021   180cm    78kg            NaN        4.0
#
#      Best Overall Rating
# 199                  NaN
# 997                  NaN
# 1331                 NaN
# 2277                 NaN
# 3143                 NaN
#
# [5 rows x 29 columns]

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])
df1
# Out:
#                   Name   Wage    Value
# 0          L. Goretzka  €115K     €91M
# 1      Bruno Fernandes  €190K   €78.5M
# 2             M. Acuña   €46K   €46.5M
# 3         K. De Bruyne  €350K  €107.5M
# 4           N. Barella  €110K   €89.5M
# ...                ...    ...      ...
# 17655    Deng Xiongtao   €500    €100K
# 17656   22 Lim Jun Sub   €500    €100K
# 17657         A. Demir    €2K     €70K
# 17658     21 S. Czajor   €500     €90K
# 17659  21 F. Jakobsson   €500     €90K
#
# [17660 rows x 3 columns]

# %%
# ztm fucntion:
# df1 = pd.DataFrame(data_frame, columns = ['Name', 'Wage', 'Value'])

# def value_to_float(x):
#     if type(x) == float or type(x) == int:
#         return x
#     if 'K' in x:
#         if len(x) > 1:
#             return float(x.replace('K', '')) * 1000
#         return 1000.0
#     if 'M' in x:
#         if len(x) > 1:
#             return float(x.replace('M', '')) * 1000000
#         return 1000000.0
#     if 'B' in x:
#         return float(x.replace('B', '')) * 1000000000
#     return 0.0

# df1['Wage'] = df1['Wage'].replace('[\€,]', '', regex = True).apply(value_to_float)
# df1['Value'] = df1['Value'].replace('[\€,]', '', regex = True).apply(value_to_float)

# df1['difference'] = df1['Value'] - df1['Wage']
# df1.sort_values('difference', ascending=False)

# %%
# grokfucntion
# 定義一個函數來處理字串或整數並轉換為整數
def convert_to_int(value):
    # 如果值是整數，直接返回
    if isinstance(value, (int, float)):
        return int(value)
    
    # 如果值是字串，進行處理
    if isinstance(value, str):
        # 去除歐元符號
        value = value.replace('€', '')
        
        # 檢查是否有 K 或 M，並進行相應的乘法
        if 'K' in value:
            return int(float(value.replace('K', '')) * 1000)
        elif 'M' in value:
            return int(float(value.replace('M', '')) * 1000000)
        else:
            return int(value)
    
    # 如果值是其他類型，返回原值或拋出錯誤
    raise ValueError(f"無法處理的值: {value}")

# 將 Wage 和 Value 欄位應用轉換
df1['Wage'] = df1['Wage'].apply(convert_to_int)
df1['Value'] = df1['Value'].apply(convert_to_int)

# 結果
df1
# Out:
#                   Name    Wage      Value
# 0          L. Goretzka  115000   91000000
# 1      Bruno Fernandes  190000   78500000
# 2             M. Acuña   46000   46500000
# 3         K. De Bruyne  350000  107500000
# 4           N. Barella  110000   89500000
# ...                ...     ...        ...
# 17655    Deng Xiongtao     500     100000
# 17656   22 Lim Jun Sub     500     100000
# 17657         A. Demir    2000      70000
# 17658     21 S. Czajor     500      90000
# 17659  21 F. Jakobsson     500      90000
#
# [17660 rows x 3 columns]

# %%
df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values(by='difference', ascending=False, inplace=True)
df1
# Out:
#                 Name    Wage      Value  difference
# 75         K. Mbappé  230000  190500000   190270000
# 180       E. Haaland  220000  148000000   147780000
# 17        F. de Jong  230000  116500000   116270000
# 214            Pedri  115000  116000000   115885000
# 25          M. Salah  270000  115500000   115230000
# ...              ...     ...        ...         ...
# 8455        14 Índio   20000          0      -20000
# 2031   14 J. Zanetti   45000       1000      -44000
# 199          R. Kent   45000          0      -45000
# 1287     14 R. Giggs   60000       1000      -59000
# 997   Z. Ibrahimović   63000          0      -63000
#
# [17660 rows x 4 columns]

# %%
import seaborn as sns
sns.set()
graph = sns.scatterplot(data=df1, x='Wage', y='Value')
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage, Value)","(@Wage, @Value)"),
    ("Name", "@Name")
])

# 使用 width 和 height 替代 plot_width 和 plot_height
p = figure(title="Soccer 2023", x_axis_label='Wage', y_axis_label='Value', width=700, height=700, tools=[TOOLTIPS])

# 繪製散點圖
p.circle(x='Wage', y='Value', size=10, source=df1)

# 顯示圖表
show(p)
